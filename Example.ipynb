# %%
from IGRApy import IGRA

# %% [markdown]
# # TEMP

# %%
x = IGRA.igra('/home/user/Desktop/IGRA/temp_00z-mly.txt',stat=['INM00043003'], save=None, save_dir='/home/user/Desktop/')

# %%
IGRA.plot_fig(x)

# %%
x.sel(lev=1000,time='2019')
# Out:
# <xarray.DataArray (time: 12)>
# array([22.5, 22.6, 24.1, 26.7, 27.7, 28.8, 27.7, 27. , 26.1, 26.3, 26.1,
#        24.9])
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01 2019-02-01 ... 2019-12-01
#     lev      int64 1000
